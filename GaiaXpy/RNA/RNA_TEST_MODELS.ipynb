# %%
import pandas as pd
import tensorflow as tf
import os

# %% [markdown]
# # Load the model

# %%
rna_balanced_model = tf.keras.models.load_model('rna_balance.keras')
rna_unbalanced_model = tf.keras.models.load_model('rna_unbalance.keras')

# %% [markdown]
# # Suspected Symbiotic Stars v1

# %% [markdown]
# ## Balance

# %%
import numpy as np
from sklearn.metrics import confusion_matrix

df_sus_sy = pd.read_csv("../../new/candidate_symbiotic_stars_v1/normalized/Suspected_SY.csv", header=None)

# predecir las probabilidades para los datos de prueba
y_probs = rna_balanced_model.predict(df_sus_sy)
y_pred = np.argmax(y_probs, axis=-1)
cm = confusion_matrix([0 for _ in range(len(df_sus_sy))], y_pred, labels=[0, 1, 2])
print(cm)
# Out:
# WARNING:tensorflow:5 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001AA23F29A80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 163ms/step
# [[14  1  0]
#  [ 0  0  0]
#  [ 0  0  0]]

# %%
df_sus_sy_normalized = pd.read_csv("../../new/candidate_symbiotic_stars_v1/calibrated_data/Suspected_SY.csv")

df5 = pd.DataFrame(y_probs)
df5['label'] = y_pred
df5.insert(0, 'source_id', df_sus_sy_normalized['source_id'])
df5.head(5)
# Out:
#              source_id         0         1         2  label
# 0  4687286621186701568  0.989815  0.005961  0.004224      0
# 1  4651824725526390016  0.982361  0.014764  0.002875      0
# 2  3321366590173335424  0.525246  0.306580  0.168174      0
# 3  5410876219867043072  0.999770  0.000224  0.000006      0
# 4  3575939163051304192  0.984526  0.015440  0.000034      0

# %%
df6 = pd.read_csv('../../new/candidate_symbiotic_stars_v1/built_dataset/suspected_SY_dataset.csv')
df6.head(5)
# Out:
#     FIND_NAME        MAIN_ID         OTYPE   SP_TYPE  \
# 0    RAW 1691        LIN 521            C*         C
# 1  [BE74] 583     [BE74] 583  LongPeriodV*     G/Ke:
# 2     StHA 55  EM* StHA   55          Mira       NaN
# 3      ZZ CMi      V* ZZ CMi  LongPeriodV*  M6I-IIep
# 4  WRAY 16−51     WRAY 16-51  LongPeriodV*        M4
#
#                         ID_Gaia  \
# 0  Gaia DR2 4687286621186701568
# 1  Gaia DR2 4651824725526390016
# 2  Gaia DR3 3321366590173335424
# 3  Gaia DR3 3155368612444708096
# 4  Gaia DR2 5410876219860836224
#
#                                                  IDS  \
# 0  RAW 1691|LIN 521|2MASS J01183570-7242213|OGLE ...
# 1  2MASS J05265014-7106350|EROS2-star lm058-2n-25...
# 2  IRAS 05440+0642|ASAS J054642+0643.7|ASAS J0546...
# 3  BD+09  1633|AN  306.1934|DO  2156|GCRV  4915|G...
# 4  IRAS 09316-4621|AKARI-IRC-V1 J0933295-463450|D...
#
#                                               OTYPES             Gaia DR3
# 0               C*|Em*|LP*|LP*|Em*|MIR|NIR|*|C*?|LP?  4687286621186701568
# 1                                   LP*|Em*|NIR|V*|*  4651824725526390016
# 2  Mi*|LP*|V*|LP*|SB*|LP*|MIR|V*|Em*|NIR|*|C*?|IR...  3321366590173335424
# 3                                LP*|NIR|V*|*|IR|LP?  3155368612444708096
# 4                            LP*|NIR|MIR|Em*|PN|*|IR  5410876219867043072

# %%
# Filtro de data frames
df_filtered = df6.merge(df5, left_on=['Gaia DR3'], right_on=['source_id'], how='inner', indicator=True)
df_filtered = df_filtered[df_filtered['_merge'] == 'both']
df_filtered = df_filtered.iloc[:, [0, 1, 7, 9, 10, 11, 12]]
df_filtered.head(5)
# Out:
#     FIND_NAME        MAIN_ID             Gaia DR3         0         1  \
# 0    RAW 1691        LIN 521  4687286621186701568  0.989815  0.005961
# 1  [BE74] 583     [BE74] 583  4651824725526390016  0.982361  0.014764
# 2     StHA 55  EM* StHA   55  3321366590173335424  0.525246  0.306580
# 3  WRAY 16−51     WRAY 16-51  5410876219867043072  0.999770  0.000224
# 4   NSV 05572      V* VX Crv  3575939163051304192  0.984526  0.015440
#
#           2  label
# 0  0.004224      0
# 1  0.002875      0
# 2  0.168174      0
# 3  0.000006      0
# 4  0.000034      0

# %%
out_name = 'rna_balanced.csv'
out_dir = '../../new/candidate_symbiotic_stars_v1/output'
if not os.path.exists(out_dir):
    os.mkdir(out_dir)

fullname = os.path.join(out_dir, out_name)
df_filtered.to_csv(fullname, header=True, index=False)

# %% [markdown]
# ## Unbalanced

# %%
import numpy as np
from sklearn.metrics import confusion_matrix

df_sus_sy = pd.read_csv("../../new/candidate_symbiotic_stars_v1/normalized/Suspected_SY.csv", header=None)

# predecir las probabilidades para los datos de prueba
y_probs = rna_unbalanced_model.predict(df_sus_sy)
y_pred = np.argmax(y_probs, axis=-1)
cm = confusion_matrix([0 for _ in range(len(df_sus_sy))], y_pred, labels=[0, 1, 2])
print(cm)
# Out:
# WARNING:tensorflow:6 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001AA22F24AE0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 63ms/step
# [[13  1  1]
#  [ 0  0  0]
#  [ 0  0  0]]

# %%
df_sus_sy_normalized = pd.read_csv("../../new/candidate_symbiotic_stars_v1/calibrated_data/Suspected_SY.csv")

df5 = pd.DataFrame(y_probs)
df5['label'] = y_pred
df5.insert(0, 'source_id', df_sus_sy_normalized['source_id'])
df5.head(5)
# Out:
#              source_id         0         1             2  label
# 0  4687286621186701568  0.883853  0.041382  7.476491e-02      0
# 1  4651824725526390016  0.933384  0.054710  1.190593e-02      0
# 2  3321366590173335424  0.546779  0.176320  2.769010e-01      0
# 3  5410876219867043072  0.982895  0.017105  1.134353e-08      0
# 4  3575939163051304192  0.978664  0.021336  9.302863e-09      0

# %%
df6 = pd.read_csv('../../new/candidate_symbiotic_stars_v1/built_dataset/suspected_SY_dataset.csv')
df6.head(5)
# Out:
#     FIND_NAME        MAIN_ID         OTYPE   SP_TYPE  \
# 0    RAW 1691        LIN 521            C*         C
# 1  [BE74] 583     [BE74] 583  LongPeriodV*     G/Ke:
# 2     StHA 55  EM* StHA   55          Mira       NaN
# 3      ZZ CMi      V* ZZ CMi  LongPeriodV*  M6I-IIep
# 4  WRAY 16−51     WRAY 16-51  LongPeriodV*        M4
#
#                         ID_Gaia  \
# 0  Gaia DR2 4687286621186701568
# 1  Gaia DR2 4651824725526390016
# 2  Gaia DR3 3321366590173335424
# 3  Gaia DR3 3155368612444708096
# 4  Gaia DR2 5410876219860836224
#
#                                                  IDS  \
# 0  RAW 1691|LIN 521|2MASS J01183570-7242213|OGLE ...
# 1  2MASS J05265014-7106350|EROS2-star lm058-2n-25...
# 2  IRAS 05440+0642|ASAS J054642+0643.7|ASAS J0546...
# 3  BD+09  1633|AN  306.1934|DO  2156|GCRV  4915|G...
# 4  IRAS 09316-4621|AKARI-IRC-V1 J0933295-463450|D...
#
#                                               OTYPES             Gaia DR3
# 0               C*|Em*|LP*|LP*|Em*|MIR|NIR|*|C*?|LP?  4687286621186701568
# 1                                   LP*|Em*|NIR|V*|*  4651824725526390016
# 2  Mi*|LP*|V*|LP*|SB*|LP*|MIR|V*|Em*|NIR|*|C*?|IR...  3321366590173335424
# 3                                LP*|NIR|V*|*|IR|LP?  3155368612444708096
# 4                            LP*|NIR|MIR|Em*|PN|*|IR  5410876219867043072

# %%
# Filtro de data frames
df_filtered = df6.merge(df5, left_on=['Gaia DR3'], right_on=['source_id'], how='inner', indicator=True)
df_filtered = df_filtered[df_filtered['_merge'] == 'both']
df_filtered = df_filtered.iloc[:, [0, 1, 7, 9, 10, 11, 12]]
df_filtered.head(5)
# Out:
#     FIND_NAME        MAIN_ID             Gaia DR3         0         1  \
# 0    RAW 1691        LIN 521  4687286621186701568  0.883853  0.041382
# 1  [BE74] 583     [BE74] 583  4651824725526390016  0.933384  0.054710
# 2     StHA 55  EM* StHA   55  3321366590173335424  0.546779  0.176320
# 3  WRAY 16−51     WRAY 16-51  5410876219867043072  0.982895  0.017105
# 4   NSV 05572      V* VX Crv  3575939163051304192  0.978664  0.021336
#
#               2  label
# 0  7.476491e-02      0
# 1  1.190593e-02      0
# 2  2.769010e-01      0
# 3  1.134353e-08      0
# 4  9.302863e-09      0

# %%
out_name = 'rna_unbalanced.csv'
out_dir = '../../new/candidate_symbiotic_stars_v1/output'
if not os.path.exists(out_dir):
    os.mkdir(out_dir)

fullname = os.path.join(out_dir, out_name)
df_filtered.to_csv(fullname, header=True, index=False)

# %% [markdown]
# # Suspected Symbiotic Stars v2

# %% [markdown]
# ## Balanced

# %%
import numpy as np
from sklearn.metrics import confusion_matrix

df_sus_sy = pd.read_csv("../../new/candidate_symbiotic_stars_v2/normalized/Suspected_SY.csv", header=None)

# predecir las probabilidades para los datos de prueba
y_probs = rna_balanced_model.predict(df_sus_sy)
y_pred = np.argmax(y_probs, axis=-1)
cm = confusion_matrix([0 for _ in range(len(df_sus_sy))], y_pred, labels=[0, 1, 2])
print(cm)
# Out:
# 1/1 [==============================] - 0s 17ms/step
# [[15  1  1]
#  [ 0  0  0]
#  [ 0  0  0]]

# %%
df_sus_sy_normalized = pd.read_csv("../../new/candidate_symbiotic_stars_v2/calibrated_data/Suspected_SY.csv")

df5 = pd.DataFrame(y_probs)
df5['label'] = y_pred
df5.insert(0, 'source_id', df_sus_sy_normalized['source_id'])
df5.head(5)
# Out:
#              source_id         0         1             2  label
# 0  6204217186929931520  0.999951  0.000049  1.937291e-13      0
# 1  4061952680197028224  0.913449  0.079856  6.694951e-03      0
# 2   670455944074475008  0.715336  0.014246  2.704186e-01      0
# 3  4068755633500598272  0.064188  0.143546  7.922659e-01      2
# 4  2060829659152816768  0.293800  0.703009  3.190844e-03      1

# %%
df5
# Out:
#               source_id         0         1             2  label
# 0   6204217186929931520  0.999951  0.000049  1.937291e-13      0
# 1   4061952680197028224  0.913449  0.079856  6.694951e-03      0
# 2    670455944074475008  0.715336  0.014246  2.704186e-01      0
# 3   4068755633500598272  0.064188  0.143546  7.922659e-01      2
# 4   2060829659152816768  0.293800  0.703009  3.190844e-03      1
# 5   2061069597507185792  0.929922  0.068729  1.348926e-03      0
# 6   2056853691965982720  0.934324  0.065361  3.146605e-04      0
# 7   2166560763171926656  0.918888  0.073652  7.459833e-03      0
# 8   2199020614163298688  0.971984  0.027984  3.194709e-05      0
# 9   2207583404553554944  0.977189  0.022261  5.500987e-04      0
# 10  4056399699798000896  0.899877  0.086188  1.393537e-02      0
# 11  4056614345105863040  0.845158  0.143268  1.157323e-02      0
# 12  4059477915655995136  0.983268  0.015722  1.010542e-03      0
# 13  4065437955878489856  0.537294  0.268100  1.946062e-01      0
# 14  4065368033805697024  0.960383  0.032904  6.713422e-03      0
# 15  4066214520316895360  0.917427  0.071427  1.114663e-02      0
# 16  5852529218799852288  0.990314  0.009371  3.142204e-04      0

# %%
df6 = pd.read_csv('../../new/candidate_symbiotic_stars_v2/built_dataset/suspected_SY_dataset.csv')
df6.head(5)
# Out:
#                   FIND_NAME              MAIN_ID                   OTYPE  \
# 0                  V748 Cen          V* V748 Cen                  EclBin
# 1               WRAY 16-294          WRAY 16-294            LongPeriodV*
# 2    DASCH J075731.1+201735  ASAS J075731+2017.6            LongPeriodV*
# 3       ASAS J174600-2321.3  ASAS J174600-2321.3  LongPeriodV*_Candidate
# 4  IPHASJ201550.96+373004.2      IRAS 20140+3720  PlanetaryNeb_Candidate
#
#   SP_TYPE                       ID_Gaia  \
# 0      Ae  Gaia DR3 6204217186929931520
# 1      K5  Gaia DR2 4061952680197028224
# 2   M0III   Gaia DR2 670455944074475008
# 3     F0I  Gaia DR2 4068755633500598272
# 4     NaN  Gaia DR2 2060829659152816768
#
#                                                  IDS  \
# 0  CD-32 10517|ALS 18924|CRTS J145936.6-332503|CS...
# 1  2MASS J17391381-2538050|DENIS J173913.8-253805...
# 2  2MASS J07573112+2017347|ASAS J075731+2017.6|DA...
# 3  2MASS J17460018-2321163|ASAS J174600-2321.3|ER...
# 4  2MASS J20155096+3730042|AKARI-IRC-V1 J2015509+...
#
#                          OTYPES             Gaia DR3
# 0          EB*|Ro*|NIR|V*|Em*|*  6204217186929931520
# 1  LP*|PN|NIR|Em*|*|C*?|ISM|LP?  4061952680197028224
# 2          SB*|LP*|NIR|V*|*|Opt   670455944074475008
# 3                  NIR|V*|*|LP?  4068755633500598272
# 4          NIR|*|C*?|IR|LP?|PN?  2060829659152816768

# %%
df6.shape
# Out:
# (20, 8)

# %%
# Filtro de data frames
df_filtered = df6.merge(df5, left_on=['Gaia DR3'], right_on=['source_id'], how='inner', indicator=True)
df_filtered = df_filtered[df_filtered['_merge'] == 'both']
df_filtered = df_filtered.iloc[:, [0, 1, 7, 9, 10, 11, 12]]
df_filtered.head(5)
# Out:
#                   FIND_NAME              MAIN_ID             Gaia DR3  \
# 0                  V748 Cen          V* V748 Cen  6204217186929931520
# 1               WRAY 16-294          WRAY 16-294  4061952680197028224
# 2    DASCH J075731.1+201735  ASAS J075731+2017.6   670455944074475008
# 3       ASAS J174600-2321.3  ASAS J174600-2321.3  4068755633500598272
# 4  IPHASJ201550.96+373004.2      IRAS 20140+3720  2060829659152816768
#
#           0         1             2  label
# 0  0.999951  0.000049  1.937291e-13      0
# 1  0.913449  0.079856  6.694951e-03      0
# 2  0.715336  0.014246  2.704186e-01      0
# 3  0.064188  0.143546  7.922659e-01      2
# 4  0.293800  0.703009  3.190844e-03      1

# %%
df_filtered.shape
# Out:
# (17, 7)

# %%
out_name = 'rna_balanced.csv'
out_dir = '../../new/candidate_symbiotic_stars_v2/output'
if not os.path.exists(out_dir):
    os.mkdir(out_dir)

fullname = os.path.join(out_dir, out_name)
df_filtered.to_csv(fullname, header=True, index=False)

# %% [markdown]
# ## Unbalanced

# %%
import numpy as np
from sklearn.metrics import confusion_matrix

df_sus_sy = pd.read_csv("../../new/candidate_symbiotic_stars_v2/normalized/Suspected_SY.csv", header=None)

# predecir las probabilidades para los datos de prueba
y_probs = rna_unbalanced_model.predict(df_sus_sy)
y_pred = np.argmax(y_probs, axis=-1)
cm = confusion_matrix([0 for _ in range(len(df_sus_sy))], y_pred, labels=[0, 1, 2])
print(cm)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# [[14  2  1]
#  [ 0  0  0]
#  [ 0  0  0]]

# %%
df_sus_sy_normalized = pd.read_csv("../../new/candidate_symbiotic_stars_v2/calibrated_data/Suspected_SY.csv")

df5 = pd.DataFrame(y_probs)
df5['label'] = y_pred
df5.insert(0, 'source_id', df_sus_sy_normalized['source_id'])
df5.head(5)
# Out:
#              source_id         0         1             2  label
# 0  6204217186929931520  0.022239  0.977761  6.522965e-09      1
# 1  4061952680197028224  0.850405  0.148644  9.505543e-04      0
# 2   670455944074475008  0.767314  0.048540  1.841462e-01      0
# 3  4068755633500598272  0.009081  0.091031  8.998880e-01      2
# 4  2060829659152816768  0.146143  0.836895  1.696214e-02      1

# %%
df6 = pd.read_csv('../../new/candidate_symbiotic_stars_v2/built_dataset/suspected_SY_dataset.csv')
df6.head(5)
# Out:
#                   FIND_NAME              MAIN_ID                   OTYPE  \
# 0                  V748 Cen          V* V748 Cen                  EclBin
# 1               WRAY 16-294          WRAY 16-294            LongPeriodV*
# 2    DASCH J075731.1+201735  ASAS J075731+2017.6            LongPeriodV*
# 3       ASAS J174600-2321.3  ASAS J174600-2321.3  LongPeriodV*_Candidate
# 4  IPHASJ201550.96+373004.2      IRAS 20140+3720  PlanetaryNeb_Candidate
#
#   SP_TYPE                       ID_Gaia  \
# 0      Ae  Gaia DR3 6204217186929931520
# 1      K5  Gaia DR2 4061952680197028224
# 2   M0III   Gaia DR2 670455944074475008
# 3     F0I  Gaia DR2 4068755633500598272
# 4     NaN  Gaia DR2 2060829659152816768
#
#                                                  IDS  \
# 0  CD-32 10517|ALS 18924|CRTS J145936.6-332503|CS...
# 1  2MASS J17391381-2538050|DENIS J173913.8-253805...
# 2  2MASS J07573112+2017347|ASAS J075731+2017.6|DA...
# 3  2MASS J17460018-2321163|ASAS J174600-2321.3|ER...
# 4  2MASS J20155096+3730042|AKARI-IRC-V1 J2015509+...
#
#                          OTYPES             Gaia DR3
# 0          EB*|Ro*|NIR|V*|Em*|*  6204217186929931520
# 1  LP*|PN|NIR|Em*|*|C*?|ISM|LP?  4061952680197028224
# 2          SB*|LP*|NIR|V*|*|Opt   670455944074475008
# 3                  NIR|V*|*|LP?  4068755633500598272
# 4          NIR|*|C*?|IR|LP?|PN?  2060829659152816768

# %%
# Filtro de data frames
df_filtered = df6.merge(df5, left_on=['Gaia DR3'], right_on=['source_id'], how='inner', indicator=True)
df_filtered = df_filtered[df_filtered['_merge'] == 'both']
df_filtered = df_filtered.iloc[:, [0, 1, 7, 9, 10, 11, 12]]
df_filtered.head(5)
# Out:
#                   FIND_NAME              MAIN_ID             Gaia DR3  \
# 0                  V748 Cen          V* V748 Cen  6204217186929931520
# 1               WRAY 16-294          WRAY 16-294  4061952680197028224
# 2    DASCH J075731.1+201735  ASAS J075731+2017.6   670455944074475008
# 3       ASAS J174600-2321.3  ASAS J174600-2321.3  4068755633500598272
# 4  IPHASJ201550.96+373004.2      IRAS 20140+3720  2060829659152816768
#
#           0         1             2  label
# 0  0.022239  0.977761  6.522965e-09      1
# 1  0.850405  0.148644  9.505543e-04      0
# 2  0.767314  0.048540  1.841462e-01      0
# 3  0.009081  0.091031  8.998880e-01      2
# 4  0.146143  0.836895  1.696214e-02      1

# %%
out_name = 'rna_unbalanced.csv'
out_dir = '../../new/candidate_symbiotic_stars_v2/output'
if not os.path.exists(out_dir):
    os.mkdir(out_dir)

fullname = os.path.join(out_dir, out_name)
df_filtered.to_csv(fullname, header=True, index=False)

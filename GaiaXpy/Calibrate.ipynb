# %%
import pandas as pd

# from google.colab import drive
# drive.mount('/content/gdrive', force_remount=True)

data = pd.read_csv("../DATA/DR3/Sy/XP_CONTINUOUS-Gaia DR3 308866701872125568.csv")
data.head()
# Out:
#             source_id          solution_id  bp_basis_function_id  \
# 0  308866701872125568  4545469030156206080                    56
#
#    bp_degrees_of_freedom  bp_n_parameters  bp_n_measurements  \
# 0                   1117               55               1172
#
#    bp_n_rejected_measurements  bp_standard_deviation  bp_chi_squared  \
# 0                          46               1.439717       2315.3008
#
#                                      bp_coefficients  ... rp_n_parameters  \
# 0  (4359777.273910325, 581384.9657800844, -77748....  ...              55
#
#   rp_n_measurements  rp_n_rejected_measurements  rp_standard_deviation  \
# 0              1325                          63               1.767027
#
#    rp_chi_squared                                    rp_coefficients  \
# 0       3965.4263  (1.5584199896418598E7, 2563048.137275565, 8089...
#
#                                rp_coefficient_errors  \
# 0  (11791.401, 12655.38, 11520.796, 10488.419, 11...
#
#                          rp_coefficient_correlations  rp_n_relevant_bases  \
# 0  (-0.20425212, -0.13397367, 0.11055192, 0.03322...                   32
#
#    rp_relative_shrinking
# 0               0.999999
#
# [1 rows x 26 columns]

# %%
# Import the tool
from gaiaxpy import calibrate
# Path to file with XP CONTINUOUS RAW data (csv, ecsv, fits, or xml)

f = data

# %%
# El espectro calibrado que es un pandas DataFrame (calibrated_spectra)
calibrated_spectra, sampling = calibrate(f)
calibrated_spectra
# Out:
#                                                         0/1 [00:00<?, ?spec/s]
#             source_id                                               flux  \
# 0  308866701872125568  [1.8545887904429264e-14, 1.9515631422050145e-1...
#
#                                           flux_error
# 0  [5.214474777878778e-15, 3.992541487358003e-15,...

# %%
#Muestreo dado en Numpy, valores que corresponden en longitudes de onda (nm)
calibrated_spectra, sampling = calibrate(f)
sampling
# Out:
#                                                         0/1 [00:00<?, ?spec/s]
# array([ 336.,  338.,  340.,  342.,  344.,  346.,  348.,  350.,  352.,
#         354.,  356.,  358.,  360.,  362.,  364.,  366.,  368.,  370.,
#         372.,  374.,  376.,  378.,  380.,  382.,  384.,  386.,  388.,
#         390.,  392.,  394.,  396.,  398.,  400.,  402.,  404.,  406.,
#         408.,  410.,  412.,  414.,  416.,  418.,  420.,  422.,  424.,
#         426.,  428.,  430.,  432.,  434.,  436.,  438.,  440.,  442.,
#         444.,  446.,  448.,  450.,  452.,  454.,  456.,  458.,  460.,
#         462.,  464.,  466.,  468.,  470.,  472.,  474.,  476.,  478.,
#         480.,  482.,  484.,  486.,  488.,  490.,  492.,  494.,  496.,
#         498.,  500.,  502.,  504.,  506.,  508.,  510.,  512.,  514.,
#         516.,  518.,  520.,  522.,  524.,  526.,  528.,  530.,  532.,
#         534.,  536.,  538.,  540.,  542.,  544.,  546.,  548.,  550.,
#         552.,  554.,  556.,  558.,  560.,  562.,  564.,  566.,  568.,
#         570.,  572.,  574.,  576.,  578.,  580.,  582.,  584.,  586.,
#         588.,  590.,  592.,  594.,  596.,  598.,  600.,  602.,  604.,
#         606.,  608.,  610.,  612.,  614.,  616.,  618.,  620.,  622.,
#         624.,  626.,  628.,  630.,  632.,  634.,  636.,  638.,  640.,
#         642.,  644.,  646.,  648.,  650.,  652.,  654.,  656.,  658.,
#         660.,  662.,  664.,  666.,  668.,  670.,  672.,  674.,  676.,
#         678.,  680.,  682.,  684.,  686.,  688.,  690.,  692.,  694.,
#         696.,  698.,  700.,  702.,  704.,  706.,  708.,  710.,  712.,
#         714.,  716.,  718.,  720.,  722.,  724.,  726.,  728.,  730.,
#         732.,  734.,  736.,  738.,  740.,  742.,  744.,  746.,  748.,
#         750.,  752.,  754.,  756.,  758.,  760.,  762.,  764.,  766.,
#         768.,  770.,  772.,  774.,  776.,  778.,  780.,  782.,  784.,
#         786.,  788.,  790.,  792.,  794.,  796.,  798.,  800.,  802.,
#         804.,  806.,  808.,  810.,  812.,  814.,  816.,  818.,  820.,
#         822.,  824.,  826.,  828.,  830.,  832.,  834.,  836.,  838.,
#         840.,  842.,  844.,  846.,  848.,  850.,  852.,  854.,  856.,
#         858.,  860.,  862.,  864.,  866.,  868.,  870.,  872.,  874.,
#         876.,  878.,  880.,  882.,  884.,  886.,  888.,  890.,  892.,
#         894.,  896.,  898.,  900.,  902.,  904.,  906.,  908.,  910.,
#         912.,  914.,  916.,  918.,  920.,  922.,  924.,  926.,  928.,
#         930.,  932.,  934.,  936.,  938.,  940.,  942.,  944.,  946.,
#         948.,  950.,  952.,  954.,  956.,  958.,  960.,  962.,  964.,
#         966.,  968.,  970.,  972.,  974.,  976.,  978.,  980.,  982.,
#         984.,  986.,  988.,  990.,  992.,  994.,  996.,  998., 1000.,
#        1002., 1004., 1006., 1008., 1010., 1012., 1014., 1016., 1018.,
#        1020.])

# %% [markdown]
# # Sampling
# Un muestreo (sampling) puede ser pasado a una función
# El sampling numpy.geomspace(330,1049.9999999999, 361) podría emplearse para mejorar la resolución en el extremo azul.

# %%
import numpy as np

first_spectra, sampling = calibrate(f)
first_spectra_geom, geom_sampling = calibrate(f, sampling=np.geomspace(330,1049.9999999999, 361))

first_spectra_geom
# Out:
#                                                         0/1 [00:00<?, ?spec/s]
#             source_id                                               flux  \
# 0  308866701872125568  [2.0104343917082907e-13, 9.858403214351052e-14...
#
#                                           flux_error
# 0  [4.5672839645220154e-14, 2.3217774436794285e-1...

# %%
geom_sampling
# Out:
# array([ 330.        ,  331.06270585,  332.12883396,  333.19839534,
#         334.27140105,  335.34786218,  336.42778986,  337.51119526,
#         338.59808957,  339.68848403,  340.78238991,  341.87981851,
#         342.98078119,  344.08528932,  345.19335432,  346.30498765,
#         347.42020079,  348.53900528,  349.66141267,  350.78743458,
#         351.91708264,  353.05036853,  354.18730396,  355.32790069,
#         356.4721705 ,  357.62012524,  358.77177675,  359.92713695,
#         361.08621779,  362.24903123,  363.41558931,  364.58590407,
#         365.75998763,  366.93785211,  368.1195097 ,  369.3049726 ,
#         370.49425307,  371.6873634 ,  372.88431594,  374.08512304,
#         375.28979713,  376.49835066,  377.71079611,  378.92714603,
#         380.14741299,  381.3716096 ,  382.59974851,  383.83184242,
#         385.06790407,  386.30794624,  387.55198174,  388.80002343,
#         390.05208422,  391.30817705,  392.56831489,  393.83251079,
#         395.1007778 ,  396.37312904,  397.64957766,  398.93013685,
#         781.13809525,  783.65361047,  786.17722647,  788.70896931,
#         791.24886518,  793.79694033,  796.3532211 ,  798.91773391,
#         801.49050528,  804.07156179,  806.66093014,  809.25863708,
#         811.86470947,  814.47917425,  817.10205845,  819.73338917,
#         822.37319363,  825.0214991 ,  827.67833296,  830.34372268,
#         833.01769581,  835.70027999,  838.39150296,  841.09139252,
#         843.7999766 ,  846.51728318,  849.24334036,  851.97817633,
#         854.72181934,  857.47429776,  860.23564004,  863.00587474,
#         865.78503047,  868.57313598,  871.37022009,  874.1763117 ,
#         876.99143982,  879.81563357,  882.64892212,  885.49133477,
#         888.3429009 ,  891.20364999,  894.07361161,  896.95281542,
#         899.8412912 ,  902.73906879,  905.64617816,  908.56264935,
#         911.48851251,  914.42379789,  917.36853584,  920.32275678,
#         923.28649126,  926.25976992,  929.24262349,  932.2350828 ,
#         935.2371788 ,  938.2489425 ,  941.27040505,  944.30159768,
#         947.34255172,  950.39329861,  953.45386988,  956.52429718,
#         959.60461223,  962.69484689,  965.79503309,  968.90520289,
#         972.02538843,  975.15562197,  978.29593587,  981.44636258,
#         984.60693468,  987.77768484,  990.95864583,  994.14985053,
#         997.35133193, 1000.56312313, 1003.78525733, 1007.01776784,
#        1010.26068807, 1013.51405154, 1016.77789188, 1020.05224284,
#        1023.33713825, 1026.63261209, 1029.9386984 , 1033.25543138,
#        1036.5828453 , 1039.92097456, 1043.26985366, 1046.62951723,
#        1050.        ])

# %%
from gaiaxpy import plot_spectra

print('Default sampling')
# Do not show the legend as there's only one source in the data
first=plot_spectra(first_spectra, sampling=sampling)
print('Geometric progression (log) sampling')
second=plot_spectra(first_spectra_geom, sampling=geom_sampling)
# Out:
# Default sampling
# Geometric progression (log) sampling

# %%
data = pd.concat([first_spectra, first_spectra_geom]).reset_index(drop=True)
data['source_id'][0] = 'Sampling Default'
data['source_id'][1] = 'Geometric Progression'

data
# Out:
#                source_id                                               flux  \
# 0       Sampling Default  [1.8545887904429264e-14, 1.9515631422050145e-1...
# 1  Geometric Progression  [2.0104343917082907e-13, 9.858403214351052e-14...
#
#                                           flux_error
# 0  [5.214474777878778e-15, 3.992541487358003e-15,...
# 1  [4.5672839645220154e-14, 2.3217774436794285e-1...

# %% [markdown]
# # Truncation
# Hace referencia probablemente al proceso de eliminar o "truncar" valores atípicos o extremos en los datos de estrellas, antes de aplicar la calibración.
#
# Los valores atípicos o extremos son aquellos que están muy alejados de los valores promedio y pueden ser causados por errores en las mediciones
#
# La eliminación de estos valores puede ayudar a mejorar la precisión de la calibración, ya que se minimizan los efectos de estas mediciones anómalas.

# %%
data2 = pd.read_csv("../DATA/DR3/Sy/XP_CONTINUOUS-Gaia DR3 369176289048301312.csv")

second_source = data2 # We'll use only the second source (sourceId 4) in the demonstration

# %%
non_truncated_spectra, sampling = calibrate(second_source) # truncation is False by default
truncated_spectra, _ = calibrate(second_source, truncation=True)
# Out:
#                                                         0/1 [00:00<?, ?spec/s]

# %%
plot_spectra(non_truncated_spectra, sampling=sampling, multi=True, legend=False)

# %%
plot_spectra(truncated_spectra, sampling=sampling, multi=True, legend=False)
